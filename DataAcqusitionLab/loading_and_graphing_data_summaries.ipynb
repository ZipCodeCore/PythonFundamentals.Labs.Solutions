# %% [markdown]
# [Documentation for Dataset](https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt)

# %%
import json_helper

# %%
df_daily_summaries = json_helper.read_all_json_files('./data/daily_summaries')

# %%
df_daily_summaries
# Out:
#                     date datatype            station attributes  value  \
# 0    2018-01-01T00:00:00     PRCP  GHCND:US1DENC0001       ,,N,      0
# 1    2018-01-01T00:00:00     SNWD  GHCND:US1DENC0001      T,,N,      0
# 2    2018-01-01T00:00:00     PRCP  GHCND:US1DENC0002       ,,N,      0
# 3    2018-01-01T00:00:00     SNOW  GHCND:US1DENC0002       ,,N,      0
# 4    2018-01-01T00:00:00     SNWD  GHCND:US1DENC0002      T,,N,      0
# ..                   ...      ...                ...        ...    ...
# 164  2018-01-31T00:00:00     TMIN  GHCND:USW00013781   ,,W,2400    -93
# 165  2018-01-31T00:00:00     WDF2  GHCND:USW00013781       ,,W,    320
# 166  2018-01-31T00:00:00     WDF5  GHCND:USW00013781       ,,W,    310
# 167  2018-01-31T00:00:00     WSF2  GHCND:USW00013781       ,,W,     89
# 168  2018-01-31T00:00:00     WSF5  GHCND:USW00013781       ,,W,    116
#
#                                         source
# 0    daily_summaries_FIPS10003_jan_2018_0.json
# 1    daily_summaries_FIPS10003_jan_2018_0.json
# 2    daily_summaries_FIPS10003_jan_2018_0.json
# 3    daily_summaries_FIPS10003_jan_2018_0.json
# 4    daily_summaries_FIPS10003_jan_2018_0.json
# ..                                         ...
# 164   daily_summaries_FIPS1003_jan_2018_1.json
# 165   daily_summaries_FIPS1003_jan_2018_1.json
# 166   daily_summaries_FIPS1003_jan_2018_1.json
# 167   daily_summaries_FIPS1003_jan_2018_1.json
# 168   daily_summaries_FIPS1003_jan_2018_1.json
#
# [1169 rows x 6 columns]

# %%
df_daily_summaries['station'].value_counts()
# Out:
# GHCND:USW00013781    333
# GHCND:US1DENC0002    147
# GHCND:US1DENC0013    126
# GHCND:US1DENC0010     78
# GHCND:US1DENC0034     54
# GHCND:US1DENC0028     51
# GHCND:US1DENC0001     49
# GHCND:US1DENC0041     47
# GHCND:US1DENC0033     43
# GHCND:US1DENC0031     42
# GHCND:US1DENC0040     39
# GHCND:US1DENC0032     37
# GHCND:US1DENC0004     36
# GHCND:US1DENC0060     35
# GHCND:US1DENC0035     22
# GHCND:US1DENC0054     21
# GHCND:US1DENC0038      9
# Name: station, dtype: int64

# %%
df_daily_summaries.shape
# Out:
# (1169, 6)

# %%
temps_max = df_daily_summaries[df_daily_summaries['datatype'] == 'TMAX'][['date', 'value']]

# %%
temps_max
# Out:
#                     date  value
# 35   2018-01-01T00:00:00    -60
# 75   2018-01-02T00:00:00    -38
# 117  2018-01-03T00:00:00     -5
# 165  2018-01-04T00:00:00    -21
# 205  2018-01-05T00:00:00    -82
# 237  2018-01-06T00:00:00    -88
# 273  2018-01-07T00:00:00    -71
# 309  2018-01-08T00:00:00      6
# 336  2018-01-09T00:00:00     78
# 373  2018-01-10T00:00:00     56
# 411  2018-01-11T00:00:00    133
# 445  2018-01-12T00:00:00    167
# 486  2018-01-13T00:00:00    139
# 523  2018-01-14T00:00:00    -32
# 565  2018-01-15T00:00:00      0
# 608  2018-01-16T00:00:00     56
# 654  2018-01-17T00:00:00     22
# 693  2018-01-18T00:00:00     22
# 731  2018-01-19T00:00:00     83
# 768  2018-01-20T00:00:00    139
# 808  2018-01-21T00:00:00    117
# 839  2018-01-22T00:00:00    156
# 872  2018-01-23T00:00:00    172
# 908  2018-01-24T00:00:00     72
# 944  2018-01-25T00:00:00     28
# 981  2018-01-26T00:00:00     39
# 17   2018-01-27T00:00:00    150
# 46   2018-01-28T00:00:00    133
# 88   2018-01-29T00:00:00     78
# 124  2018-01-30T00:00:00     39
# 163  2018-01-31T00:00:00      6

# %%
temps_max['value'].describe()
# Out:
# count     31.000000
# mean      48.193548
# std       77.768640
# min      -88.000000
# 25%       -2.500000
# 50%       39.000000
# 75%      125.000000
# max      172.000000
# Name: value, dtype: float64

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = temps_max['date'].str[8:10]
y = temps_max['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Max Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Max Temperatues Jan 2018')]

# %%
temps_min = df_daily_summaries[df_daily_summaries['datatype'] == 'TMIN'][['date', 'value']]

# %%
temps_min
# Out:
#                     date  value
# 36   2018-01-01T00:00:00   -149
# 76   2018-01-02T00:00:00   -116
# 118  2018-01-03T00:00:00   -132
# 166  2018-01-04T00:00:00    -93
# 206  2018-01-05T00:00:00   -121
# 238  2018-01-06T00:00:00   -138
# 274  2018-01-07T00:00:00   -166
# 310  2018-01-08T00:00:00   -105
# 337  2018-01-09T00:00:00    -60
# 374  2018-01-10T00:00:00    -49
# 412  2018-01-11T00:00:00     33
# 446  2018-01-12T00:00:00     83
# 487  2018-01-13T00:00:00    -71
# 524  2018-01-14T00:00:00   -105
# 566  2018-01-15T00:00:00    -88
# 609  2018-01-16T00:00:00    -16
# 655  2018-01-17T00:00:00    -77
# 694  2018-01-18T00:00:00    -99
# 732  2018-01-19T00:00:00    -66
# 769  2018-01-20T00:00:00    -38
# 809  2018-01-21T00:00:00    -32
# 840  2018-01-22T00:00:00     39
# 873  2018-01-23T00:00:00     44
# 909  2018-01-24T00:00:00      6
# 945  2018-01-25T00:00:00    -38
# 982  2018-01-26T00:00:00    -66
# 18   2018-01-27T00:00:00    -49
# 47   2018-01-28T00:00:00     72
# 89   2018-01-29T00:00:00     33
# 125  2018-01-30T00:00:00    -55
# 164  2018-01-31T00:00:00    -93

# %%
temps_min['value'].describe()
# Out:
# count     31.000000
# mean     -55.225806
# std       65.749378
# min     -166.000000
# 25%     -102.000000
# 50%      -66.000000
# 75%      -24.000000
# max       83.000000
# Name: value, dtype: float64

# %%
x = temps_min['date'].str[8:10]
y = temps_min['value'] / 10

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, y)
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Min Temperatues Jan 2018')]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
ax.plot(x, temps_max['value'] / 10, color='red')
ax.plot(x, temps_min['value'] / 10, color='blue')
ax.grid()
ax.set(xlabel='day of month', ylabel='temperature in celsius', title='Min & Max Temperatues Jan 2018')
# Out:
# [Text(0, 0.5, 'temperature in celsius'),
#  Text(0.5, 0, 'day of month'),
#  Text(0.5, 1.0, 'Min & Max Temperatues Jan 2018')]
