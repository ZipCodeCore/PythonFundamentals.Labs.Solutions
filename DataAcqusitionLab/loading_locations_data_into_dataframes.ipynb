# %%
import pandas as pd
import numpy as np
import os
import json

# %% [markdown]
# ## Read a single JSON

# %%
def read_json(file_path):
    json_input = None
    with open(file_path) as f:
        json_input = json.load(f)
    return json_input

# %%
file_path = os.path.join("./data", "locations_4.json")
json_input = read_json(file_path)

# %%
json_input
# Out:
# xdate': '2019-11-22',
#    'name': 'Humphreys County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47085'},
#   {'mindate': '1940-04-19',
#    'maxdate': '2019-11-22',
#    'name': 'Jackson County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47087'},
#   {'mindate': '1905-02-05',
#    'maxdate': '2019-11-22',
#    'name': 'Jefferson County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47089'},
#   {'mindate': '1897-07-01',
#    'maxdate': '2019-11-22',
#    'name': 'Johnson County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47091'},
#   {'mindate': '1910-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Knox County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47093'},
#   {'mindate': '1924-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Lake County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47095'},
#   {'mindate': '1926-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Lauderdale County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47097'},
#   {'mindate': '1895-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Lawrence County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47099'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Lewis County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47101'},
#   {'mindate': '1898-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Lincoln County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47103'},
#   {'mindate': '1904-07-01',
#    'maxdate': '2019-11-22',
#    'name': 'Loudon County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47105'},
#   {'mindate': '1924-07-01',
#    'maxdate': '2019-11-22',
#    'name': 'McMinn County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47107'},
#   {'mindate': '1923-10-01',
#    'maxdate': '2019-11-22',
#    'name': 'McNairy County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47109'},
#   {'mindate': '1942-10-01',
#    'maxdate': '2019-11-22',
#    'name': 'Macon County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47111'},
#   {'mindate': '1891-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Madison County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47113'},
#   {'mindate': '1940-02-01',
#    'maxdate': '2019-11-22',
#    'name': 'Marion County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47115'},
#   {'mindate': '1890-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Marshall County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47117'},
#   {'mindate': '1890-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Maury County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47119'},
#   {'mindate': '1895-11-01',
#    'maxdate': '2019-11-22',
#    'name': 'Meigs County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47121'},
#   {'mindate': '1896-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Monroe County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47123'},
#   {'mindate': '1890-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Montgomery County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47125'},
#   {'mindate': '1941-11-01',
#    'maxdate': '2019-11-22',
#    'name': 'Moore County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47127'},
#   {'mindate': '1890-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Morgan County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47129'},
#   {'mindate': '1891-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Obion County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47131'},
#   {'mindate': '1910-11-01',
#    'maxdate': '2019-11-22',
#    'name': 'Overton County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47133'},
#   {'mindate': '1941-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Perry County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47135'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Pickett County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47137'},
#   {'mindate': '1890-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Polk County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47139'},
#   {'mindate': '1904-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Putnam County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47141'},
#   {'mindate': '1935-03-01',
#    'maxdate': '2019-11-22',
#    'name': 'Rhea County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47143'},
#   {'mindate': '1884-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Roane County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47145'},
#   {'mindate': '1897-03-01',
#    'maxdate': '2019-11-22',
#    'name': 'Robertson County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47147'},
#   {'mindate': '1890-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Rutherford County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47149'},
#   {'mindate': '1908-02-01',
#    'maxdate': '2019-11-22',
#    'name': 'Scott County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47151'},
#   {'mindate': '1909-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Sequatchie County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47153'},
#   {'mindate': '1906-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Sevier County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47155'},
#   {'mindate': '1928-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Shelby County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47157'},
#   {'mindate': '1897-12-15',
#    'maxdate': '2019-11-22',
#    'name': 'Smith County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47159'},
#   {'mindate': '1897-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Stewart County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47161'},
#   {'mindate': '1895-09-01',
#    'maxdate': '2019-11-22',
#    'name': 'Sullivan County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47163'},
#   {'mindate': '1901-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Sumner County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47165'},
#   {'mindate': '1890-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Tipton County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47167'},
#   {'mindate': '1941-09-01',
#    'maxdate': '2019-11-22',
#    'name': 'Trousdale County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47169'},
#   {'mindate': '1926-11-01',
#    'maxdate': '2019-11-22',
#    'name': 'Unicoi County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47171'},
#   {'mindate': '1948-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Union County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47173'},
#   {'mindate': '1949-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Van Buren County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47175'},
#   {'mindate': '1891-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Warren County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47177'},
#   {'mindate': '1926-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Washington County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47179'},
#   {'mindate': '1891-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Wayne County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47181'},
#   {'mindate': '1924-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Weakley County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47183'},
#   {'mindate': '1939-10-23',
#    'maxdate': '2019-11-22',
#    'name': 'White County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47185'},
#   {'mindate': '1891-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Williamson County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47187'},
#   {'mindate': '1890-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Wilson County, TN',
#    'datacoverage': 1,
#    'id': 'FIPS:47189'},
#   {'mindate': '1852-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Texas',
#    'datacoverage': 1,
#    'id': 'FIPS:48'},
#   {'mindate': '1904-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Anderson County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48001'},
#   {'mindate': '1914-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Andrews County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48003'},
#   {'mindate': '1940-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Angelina County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48005'},
#   {'mindate': '1944-03-22',
#    'maxdate': '2019-11-22',
#    'name': 'Aransas County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48007'},
#   {'mindate': '1910-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Archer County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48009'},
#   {'mindate': '1904-10-01',
#    'maxdate': '2019-11-22',
#    'name': 'Armstrong County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48011'},
#   {'mindate': '1907-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Atascosa County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48013'},
#   {'mindate': '1910-10-01',
#    'maxdate': '2019-11-22',
#    'name': 'Austin County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48015'},
#   {'mindate': '1921-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Bailey County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48017'},
#   {'mindate': '1941-10-01',
#    'maxdate': '2019-11-22',
#    'name': 'Bandera County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48019'},
#   {'mindate': '1900-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Bastrop County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48021'},
#   {'mindate': '1905-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Baylor County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48023'},
#   {'mindate': '1895-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Bee County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48025'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Bell County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48027'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Bexar County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48029'},
#   {'mindate': '1896-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Blanco County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48031'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Borden County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48033'},
#   {'mindate': '1900-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Bosque County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48035'},
#   {'mindate': '1909-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Bowie County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48037'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Brazoria County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48039'},
#   {'mindate': '1882-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Brazos County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48041'},
#   {'mindate': '1896-07-01',
#    'maxdate': '2019-11-22',
#    'name': 'Brewster County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48043'},
#   {'mindate': '1925-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Briscoe County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48045'},
#   {'mindate': '1907-03-01',
#    'maxdate': '2019-11-22',
#    'name': 'Brooks County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48047'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Brown County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48049'},
#   {'mindate': '1908-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Burleson County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48051'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Burnet County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48053'},
#   {'mindate': '1897-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Caldwell County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48055'},
#   {'mindate': '1901-02-01',
#    'maxdate': '2019-11-22',
#    'name': 'Calhoun County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48057'},
#   {'mindate': '1911-03-17',
#    'maxdate': '2019-11-22',
#    'name': 'Callahan County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48059'},
#   {'mindate': '1889-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Cameron County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48061'},
#   {'mindate': '1949-04-29',
#    'maxdate': '2019-11-22',
#    'name': 'Camp County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48063'},
#   {'mindate': '1911-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Carson County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48065'},
#   {'mindate': '1930-09-01',
#    'maxdate': '2019-11-22',
#    'name': 'Cass County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48067'},
#   {'mindate': '1906-03-01',
#    'maxdate': '2019-11-22',
#    'name': 'Castro County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48069'},
#   {'mindate': '1909-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Chambers County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48071'},
#   {'mindate': '1897-09-01',
#    'maxdate': '2019-11-22',
#    'name': 'Cherokee County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48073'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Childress County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48075'},
#   {'mindate': '1897-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Clay County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48077'},
#   {'mindate': '1935-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Cochran County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48079'},
#   {'mindate': '1908-03-01',
#    'maxdate': '2019-11-22',
#    'name': 'Coke County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48081'},
#   {'mindate': '1894-03-01',
#    'maxdate': '2019-11-22',
#    'name': 'Coleman County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48083'},
#   {'mindate': '1898-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Collin County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48085'},
#   {'mindate': '1912-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Collingsworth County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48087'},
#   {'mindate': '1899-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Colorado County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48089'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Comal County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48091'},
#   {'mindate': '1901-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Comanche County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48093'},
#   {'mindate': '1911-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Concho County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48095'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Cooke County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48097'},
#   {'mindate': '1900-02-01',
#    'maxdate': '2019-11-22',
#    'name': 'Coryell County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48099'},
#   {'mindate': '1913-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Cottle County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48101'},
#   {'mindate': '1940-02-26',
#    'maxdate': '2019-11-22',
#    'name': 'Crane County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48103'},
#   {'mindate': '1940-04-24',
#    'maxdate': '2019-11-22',
#    'name': 'Crockett County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48105'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Crosby County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48107'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Culberson County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48109'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Dallam County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48111'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Dallas County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48113'},
#   {'mindate': '1910-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Dawson County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48115'},
#   {'mindate': '1895-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Deaf Smith County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48117'},
#   {'mindate': '1944-02-08',
#    'maxdate': '2019-11-22',
#    'name': 'Delta County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48119'},
#   {'mindate': '1913-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Denton County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48121'},
#   {'mindate': '1940-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'DeWitt County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48123'},
#   {'mindate': '1911-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Dickens County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48125'},
#   {'mindate': '1912-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Dimmit County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48127'},
#   {'mindate': '1904-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Donley County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48129'},
#   {'mindate': '1940-03-25',
#    'maxdate': '2019-11-22',
#    'name': 'Duval County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48131'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Eastland County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48133'},
#   {'mindate': '1943-09-01',
#    'maxdate': '2019-11-22',
#    'name': 'Ector County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48135'},
#   {'mindate': '1894-03-01',
#    'maxdate': '2019-11-22',
#    'name': 'Edwards County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48137'},
#   {'mindate': '1897-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Ellis County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48139'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'El Paso County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48141'},
#   {'mindate': '1897-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Erath County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48143'},
#   {'mindate': '1902-08-05',
#    'maxdate': '2019-11-22',
#    'name': 'Falls County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48145'},
#   {'mindate': '1898-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Fannin County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48147'},
#   {'mindate': '1908-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Fayette County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48149'},
#   {'mindate': '1893-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Fisher County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48151'},
#   {'mindate': '1939-08-02',
#    'maxdate': '2019-11-22',
#    'name': 'Floyd County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48153'},
#   {'mindate': '1916-08-01',
#    'maxdate': '2019-11-22',
#    'name': 'Foard County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48155'},
#   {'mindate': '1893-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Fort Bend County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48157'},
#   {'mindate': '1909-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Franklin County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48159'},
#   {'mindate': '1913-10-01',
#    'maxdate': '2019-11-22',
#    'name': 'Freestone County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48161'},
#   {'mindate': '1902-03-01',
#    'maxdate': '2019-11-22',
#    'name': 'Frio County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48163'},
#   {'mindate': '1922-08-05',
#    'maxdate': '2019-11-22',
#    'name': 'Gaines County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48165'},
#   {'mindate': '1897-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Galveston County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48167'},
#   {'mindate': '1910-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Garza County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48169'},
#   {'mindate': '1896-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Gillespie County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48171'},
#   {'mindate': '1912-10-01',
#    'maxdate': '2019-11-22',
#    'name': 'Glasscock County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48173'},
#   {'mindate': '1912-09-01',
#    'maxdate': '2019-11-22',
#    'name': 'Goliad County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48175'},
#   {'mindate': '1915-04-01',
#    'maxdate': '2019-11-22',
#    'name': 'Gonzales County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48177'},
#   {'mindate': '1907-01-27',
#    'maxdate': '2019-11-22',
#    'name': 'Gray County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48179'},
#   {'mindate': '1897-05-01',
#    'maxdate': '2019-11-22',
#    'name': 'Grayson County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48181'},
#   {'mindate': '1902-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Gregg County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48183'},
#   {'mindate': '1914-06-01',
#    'maxdate': '2019-11-22',
#    'name': 'Grimes County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48185'},
#   {'mindate': '1922-12-01',
#    'maxdate': '2019-11-22',
#    'name': 'Guadalupe County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48187'},
#   {'mindate': '1897-01-01',
#    'maxdate': '2019-11-22',
#    'name': 'Hale County, TX',
#    'datacoverage': 1,
#    'id': 'FIPS:48189'}]}

# %% [markdown]
# ## Convert JSON Into a DataFrame

# %%
locations = json_input['results']

# %%
df = pd.DataFrame(locations)

# %%
df
# Out:
#         mindate     maxdate                     name  datacoverage          id
# 0    1893-02-01  2019-11-22  Powder River County, MT           1.0  FIPS:30075
# 1    1893-01-01  2019-11-22        Powell County, MT           1.0  FIPS:30077
# 2    1904-11-01  2019-11-22       Prairie County, MT           1.0  FIPS:30079
# 3    1895-06-12  2019-11-22       Ravalli County, MT           1.0  FIPS:30081
# 4    1900-05-04  2019-11-22      Richland County, MT           1.0  FIPS:30083
# ..          ...         ...                      ...           ...         ...
# 995  1897-05-01  2019-11-22       Grayson County, TX           1.0  FIPS:48181
# 996  1902-01-01  2019-11-22         Gregg County, TX           1.0  FIPS:48183
# 997  1914-06-01  2019-11-22        Grimes County, TX           1.0  FIPS:48185
# 998  1922-12-01  2019-11-22     Guadalupe County, TX           1.0  FIPS:48187
# 999  1897-01-01  2019-11-22          Hale County, TX           1.0  FIPS:48189
#
# [1000 rows x 5 columns]

# %%
df[df['name'].str.contains('Durham') == True]
# Out:
#         mindate     maxdate               name  datacoverage          id
# 293  1891-01-01  2019-11-22  Durham County, NC           1.0  FIPS:37063

# %% [markdown]
# ## Read Multiple JSON Files

# %%
def read_all_json_files():
    JSON_ROOT = os.path.join('./', 'data/')
    for root, _, files in os.walk(JSON_ROOT):
        result = pd.DataFrame()
        for f in files:
            if f.endswith('json'):
                json_content = read_json(JSON_ROOT + f)
                temp_df = pd.DataFrame(json_content['results'])
                temp_df['source'] = f
                result = result.append(temp_df)
    return result

# %%
df = read_all_json_files()

# %%
df.shape
# Out:
# (38859, 6)

# %%
df.head()
# Out:
#       mindate     maxdate                      name  datacoverage         id  \
# 0  1955-11-01  2019-11-22      Huntington, VT 05462          1.00  ZIP:05462
# 1  1997-03-06  2019-11-22   Isle la Motte, VT 05463          0.95  ZIP:05463
# 2  1995-05-08  2019-11-22  Jeffersonville, VT 05464          1.00  ZIP:05464
# 3  1995-05-08  2019-11-22         Jericho, VT 05465          1.00  ZIP:05465
# 4  1997-03-06  2019-11-22          Milton, VT 05468          0.95  ZIP:05468
#
#               source
# 0  locations_10.json
# 1  locations_10.json
# 2  locations_10.json
# 3  locations_10.json
# 4  locations_10.json

# %% [markdown]
# ## Validate Records Are Unique

# %%
df['id'].describe()
# Out:
# count         38859
# unique        38859
# top       ZIP:74432
# freq              1
# Name: id, dtype: object

# %%
df[df['id'].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [mindate, maxdate, name, datacoverage, id, source]
# Index: []

# %%
df[df['id'] == "CITY:TU000041"]
# Out:
#         mindate     maxdate        name  datacoverage             id  \
# 999  1974-08-01  2019-11-16  Mersin, TU        0.9986  CITY:TU000041
#
#                source
# 999  locations_0.json

# %%
df[df['id'] == "CLIM:0405"]
# Out:
#         mindate     maxdate                                name  datacoverage  \
# 999  1893-10-10  2019-11-22  Southwest Arizona Climate Division           1.0
#
#             id            source
# 999  CLIM:0405  locations_1.json

# %%
df['source'].describe()
# Out:
# count                38859
# unique                  39
# top       locations_1.json
# freq                  1000
# Name: source, dtype: object

# %%
df[df['source'] == "locations_38.json"].count()
# Out:
# mindate         859
# maxdate         859
# name            859
# datacoverage    859
# id              859
# source          859
# dtype: int64

# %%
de_locs = df[df['name'].str.contains("DE") == True]
